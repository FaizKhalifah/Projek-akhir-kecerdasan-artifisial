# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("semustafacevik/software-defect-prediction")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\HP\.cache\kagglehub\datasets\semustafacevik\software-defect-prediction\versions\1
